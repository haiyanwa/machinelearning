# %%
import numpy as np
import os.path
import re
import cv2

dir = "testimg_datala/16-5566_09-06-2016_002_SB/0700/"
first_file_path = dir + "image12630.jpg"
prefix = "image"
ext = ".jpg"
step = 1

n = 0

frame0 = cv2.imread(first_file_path)
gray_frame0 = cv2.cvtColor(frame0, cv2.COLOR_BGR2GRAY)

for dirName, subdirList, fileList in os.walk(dir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        file = re.sub(prefix,"",fname)
        file = re.sub(ext,"",file)
        file_path = dir + fname
        
        frame = cv2.imread(file_path)
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        ##compare with the previous
        if gray_frame0 is not None:
            #framediff = cv2.absdiff(gray_frame0,gray_frame)
            framediff = cv2.absdiff(frame0,frame)
            savepath = "./masked_bgr/" + fname
            print(savepath)
            cv2.imwrite(savepath, framediff)
        else:
            gray_frame0 = gray_frame
        
        next = int(file) + step
        next_file = dir + prefix + str(next) + ext
        
        ##when there's next frame
        if os.path.isfile(next_file):
            gray_frame0 = gray_frame
        else:
            gray_frame0 = None
            continue
# Out:
# Found directory: testimg_datala/16-5566_09-06-2016_002_SB/0700/
# ./masked_bgr/image12630.jpg
# ./masked_bgr/image12631.jpg
# ./masked_bgr/image12632.jpg
# ./masked_bgr/image12633.jpg
# ./masked_bgr/image12634.jpg
# ./masked_bgr/image12635.jpg
# ./masked_bgr/image12636.jpg
# ./masked_bgr/image12637.jpg
# ./masked_bgr/image12638.jpg
# ./masked_bgr/image12639.jpg
# ./masked_bgr/image12640.jpg
# ./masked_bgr/image12641.jpg
# ./masked_bgr/image12642.jpg
# ./masked_bgr/image12643.jpg
# ./masked_bgr/image12644.jpg
# ./masked_bgr/image12645.jpg
# ./masked_bgr/image12646.jpg
# ./masked_bgr/image12647.jpg
# ./masked_bgr/image12648.jpg
# ./masked_bgr/image12649.jpg
# ./masked_bgr/image12650.jpg
# ./masked_bgr/image12651.jpg
# ./masked_bgr/image12652.jpg
# ./masked_bgr/image12653.jpg
# ./masked_bgr/image12654.jpg
# ./masked_bgr/image12655.jpg
# ./masked_bgr/image12656.jpg
# ./masked_bgr/image12657.jpg
# ./masked_bgr/image12658.jpg
# ./masked_bgr/image12659.jpg
# ./masked_bgr/image12660.jpg
# ./masked_bgr/image12661.jpg
# ./masked_bgr/image12662.jpg
# ./masked_bgr/image12663.jpg
# ./masked_bgr/image12664.jpg
# ./masked_bgr/image12665.jpg
# ./masked_bgr/image12666.jpg
# ./masked_bgr/image12667.jpg
# ./masked_bgr/image12668.jpg
# ./masked_bgr/image12669.jpg
# ./masked_bgr/image12670.jpg
# ./masked_bgr/image12671.jpg
# ./masked_bgr/image12672.jpg
# ./masked_bgr/image12673.jpg
# ./masked_bgr/image12674.jpg
# ./masked_bgr/image12675.jpg
# ./masked_bgr/image12676.jpg
# ./masked_bgr/image12677.jpg
# ./masked_bgr/image12678.jpg
# ./masked_bgr/image12679.jpg
# ./masked_bgr/image12680.jpg
# ./masked_bgr/image12681.jpg
# ./masked_bgr/image12682.jpg
# ./masked_bgr/image12683.jpg
# ./masked_bgr/image12684.jpg
# ./masked_bgr/image12685.jpg
# ./masked_bgr/image12686.jpg
# ./masked_bgr/image12687.jpg
# ./masked_bgr/image12688.jpg
# ./masked_bgr/image12689.jpg
# ./masked_bgr/image12690.jpg
# ./masked_bgr/image12691.jpg
# ./masked_bgr/image12692.jpg
# ./masked_bgr/image12693.jpg
# ./masked_bgr/image12694.jpg
# ./masked_bgr/image12695.jpg
# ./masked_bgr/image12696.jpg
# ./masked_bgr/image12697.jpg
# ./masked_bgr/image12698.jpg
# ./masked_bgr/image12699.jpg
# ./masked_bgr/image27751.jpg
# ./masked_bgr/image27752.jpg
# ./masked_bgr/image27753.jpg
# ./masked_bgr/image27754.jpg
# ./masked_bgr/image27755.jpg
# ./masked_bgr/image27756.jpg
# ./masked_bgr/image27757.jpg
# ./masked_bgr/image27758.jpg
# ./masked_bgr/image27759.jpg
# ./masked_bgr/image27760.jpg
# ./masked_bgr/image27761.jpg
# ./masked_bgr/image27762.jpg
# ./masked_bgr/image27763.jpg
# ./masked_bgr/image27764.jpg
# ./masked_bgr/image27765.jpg
# ./masked_bgr/image27766.jpg
# ./masked_bgr/image27767.jpg
# ./masked_bgr/image27768.jpg
# ./masked_bgr/image27769.jpg
# ./masked_bgr/image27770.jpg
# ./masked_bgr/image27771.jpg
# ./masked_bgr/image27772.jpg
# ./masked_bgr/image27773.jpg
# ./masked_bgr/image27774.jpg
# ./masked_bgr/image27775.jpg
# ./masked_bgr/image27776.jpg
# ./masked_bgr/image27777.jpg
# ./masked_bgr/image27778.jpg
# ./masked_bgr/image27779.jpg
# ./masked_bgr/image27780.jpg
# ./masked_bgr/image27781.jpg
# ./masked_bgr/image27782.jpg
# ./masked_bgr/image27783.jpg
# ./masked_bgr/image27784.jpg
# ./masked_bgr/image27785.jpg
# ./masked_bgr/image27786.jpg
# ./masked_bgr/image27787.jpg
# ./masked_bgr/image27788.jpg
# ./masked_bgr/image27789.jpg
# ./masked_bgr/image27790.jpg
# ./masked_bgr/image27791.jpg
# ./masked_bgr/image27792.jpg
# ./masked_bgr/image27793.jpg
# ./masked_bgr/image27794.jpg
# ./masked_bgr/image27795.jpg
# ./masked_bgr/image27796.jpg
# ./masked_bgr/image27797.jpg
# ./masked_bgr/image27798.jpg
# ./masked_bgr/image27799.jpg
# ./masked_bgr/image35211.jpg
# ./masked_bgr/image35212.jpg
# ./masked_bgr/image35213.jpg
# ./masked_bgr/image35214.jpg
# ./masked_bgr/image35215.jpg
# ./masked_bgr/image35216.jpg
# ./masked_bgr/image35217.jpg
# ./masked_bgr/image35218.jpg
# ./masked_bgr/image35219.jpg
# ./masked_bgr/image35220.jpg
# ./masked_bgr/image35221.jpg
# ./masked_bgr/image35222.jpg
# ./masked_bgr/image35223.jpg
# ./masked_bgr/image35224.jpg
# ./masked_bgr/image35225.jpg
# ./masked_bgr/image35226.jpg
# ./masked_bgr/image35227.jpg
# ./masked_bgr/image35228.jpg
# ./masked_bgr/image35229.jpg
# ./masked_bgr/image35230.jpg
# ./masked_bgr/image35231.jpg
# ./masked_bgr/image35232.jpg
# ./masked_bgr/image35233.jpg
# ./masked_bgr/image35234.jpg
# ./masked_bgr/image35235.jpg
# ./masked_bgr/image35236.jpg
# ./masked_bgr/image35237.jpg
# ./masked_bgr/image35238.jpg
# ./masked_bgr/image35239.jpg
# ./masked_bgr/image35240.jpg
# ./masked_bgr/image35241.jpg
# ./masked_bgr/image35242.jpg
# ./masked_bgr/image35243.jpg
# ./masked_bgr/image35244.jpg
# ./masked_bgr/image35245.jpg
# ./masked_bgr/image35246.jpg
# ./masked_bgr/image35247.jpg
# ./masked_bgr/image35248.jpg
# ./masked_bgr/image35249.jpg
# ./masked_bgr/image35250.jpg
# ./masked_bgr/image35251.jpg
# ./masked_bgr/image35252.jpg
# ./masked_bgr/image35253.jpg
# ./masked_bgr/image35254.jpg
# ./masked_bgr/image35255.jpg
# ./masked_bgr/image35256.jpg
# ./masked_bgr/image35257.jpg
# ./masked_bgr/image35258.jpg
# ./masked_bgr/image35259.jpg
# ./masked_bgr/image35260.jpg
# ./masked_bgr/image35261.jpg
# ./masked_bgr/image35262.jpg
# ./masked_bgr/image35263.jpg
# ./masked_bgr/image35264.jpg
# ./masked_bgr/image35265.jpg
# ./masked_bgr/image35266.jpg
# ./masked_bgr/image35267.jpg
# ./masked_bgr/image35268.jpg
# ./masked_bgr/image35269.jpg

# %%
import re
filename = "image27750.jpg"
file = re.sub("image","",filename)
file = re.sub(".jpg","",file)
print(file)
# Out:
# 27750
